# %% [markdown]
# # Identifying high flyers

# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
from sklearn.tree import DecisionTreeClassifier
random.seed(365)

# %%
# Globals
PCT_TRAIN = 0.6
N_ITERS = 50

# %%
# Function to fit a regression tree to data

def train_test_eval(features, labels, trial_name):
    
    # Math to split into train / test
    n_rows = features.shape[0]
    n_rows_training = round(PCT_TRAIN * n_rows)
    random_index = list(range(n_rows))
    
    # Track feature importance throughout the iterations
    all_feature_importance = {}
    for feature_name in list(features):
        all_feature_importance[feature_name] = []
        
    # Track MCR throughout the iterations
    mcrs = []

    # Fit the tree several times
    for i in range(N_ITERS):

        random.shuffle(random_index)

        # Get training data
        train_index = random_index[: n_rows_training]
        train_features = features.iloc[train_index]
        train_labels = labels[train_index]

        # Get test data
        test_index = random_index[n_rows_training :]
        test_features = features.loc[test_index]
        test_labels = labels[test_index]

        # Create a tree using the training data
        tree = DecisionTreeClassifier()
        tree.fit(train_features, train_labels)

        # Predict on the test data
        predicted_labels = tree.predict(test_features)

        # Calculate how well it performed (MCR)
        n_wrong = sum(test_labels != predicted_labels)
        mcr = n_wrong / len(test_labels)
        mcrs.append(mcr)
        
        # Check feature importances
        for (feature_name, importance) in zip(list(features), tree.feature_importances_):
            all_feature_importance[feature_name].append(importance)
        importances = pd.DataFrame({
            "feature_name": list(features),
            "importance": tree.feature_importances_})

        # Print out the results
        print("\nTrial #{}:".format(i + 1))
        print("Misclassified {} of {} points | MCR = {}".format(n_wrong, len(test_labels), mcr))
        print("Five most useful features:")
        print(importances.sort_values(by="importance", ascending=False).head())

    # Create and save a plot of feature importance
    df = pd.DataFrame(all_feature_importance)
    plt.figure(figsize=(11, 8))
    plt.subplot(212)
    for i in range(N_ITERS):
        plt.scatter(df.columns, df.loc[i], s=10, c="black")
    plt.title("Feature Importance, trial={}".format(trial_name))
    plt.savefig("plots/{}_feat.png".format(trial_name))
    
    # Create and save a plot of MCRs
    plt.figure(figsize=(11, 8))
    plt.hist(mcrs)
    plt.title("Histogram of MCRs, trial={}".format(trial_name))
    plt.savefig("plots/{}_hist.png".format(trial_name))
        
    return

# %% [markdown]
# ## `baseline.csv` data

# %%
# Data cleaning

# Some columns / rows have too many NAs
baseline = pd.read_csv("data/baseline.csv")
baseline.drop(axis="columns", labels=["rec_attended_school", "dist_food_market"], inplace=True)
baseline.dropna(axis="index", how="any", inplace=True)
baseline.reset_index(inplace=True)
baseline.drop(axis="columns", labels=["index"], inplace=True)

# Recode 
baseline = baseline.replace("Willing to wait at least once", "1")
baseline = baseline.replace("Never willing to wait", "0")
baseline = baseline.astype({"imp_dich": "int32"})

# %% [markdown]
# ### `HF2` as label

# %%
# Fit a basic classification tree to the baseline data with HF2 as labels

features = baseline[[
    "hhsize", "able", "rec_age", "imp_dich", "future1yr",
    "asst_idx", "lvstk_idx", "prod_idx", "any_savings"]]

labels = baseline["HF2"]

train_test_eval(features, labels, "baseline_hf2")
# Out:
# Trial #1:
# Misclassified 44 of 296 points | MCR = 0.14864864864864866
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.214048
# 7     prod_idx    0.211404
# 2      rec_age    0.162575
# 0       hhsize    0.132557
# 1         able    0.111905
#
# Trial #2:
# Misclassified 49 of 296 points | MCR = 0.16554054054054054
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.255291
# 2      rec_age    0.181220
# 7     prod_idx    0.168344
# 0       hhsize    0.158382
# 6    lvstk_idx    0.080931
#
# Trial #3:
# Misclassified 39 of 296 points | MCR = 0.13175675675675674
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.337784
# 0       hhsize    0.188414
# 7     prod_idx    0.184695
# 2      rec_age    0.134625
# 6    lvstk_idx    0.094244
#
# Trial #4:
# Misclassified 47 of 296 points | MCR = 0.15878378378378377
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.406858
# 7     prod_idx    0.142527
# 2      rec_age    0.132603
# 6    lvstk_idx    0.104873
# 0       hhsize    0.104536
#
# Trial #5:
# Misclassified 41 of 296 points | MCR = 0.13851351351351351
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.279895
# 7     prod_idx    0.187900
# 0       hhsize    0.179842
# 2      rec_age    0.108251
# 6    lvstk_idx    0.076422
#
# Trial #6:
# Misclassified 54 of 296 points | MCR = 0.18243243243243243
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.229273
# 5     asst_idx    0.213253
# 2      rec_age    0.191207
# 0       hhsize    0.162120
# 6    lvstk_idx    0.077152
#
# Trial #7:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.271965
# 2      rec_age    0.226061
# 7     prod_idx    0.170930
# 0       hhsize    0.135163
# 6    lvstk_idx    0.101373
#
# Trial #8:
# Misclassified 42 of 296 points | MCR = 0.14189189189189189
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.291441
# 2      rec_age    0.194899
# 6    lvstk_idx    0.152421
# 0       hhsize    0.129186
# 1         able    0.098213
#
# Trial #9:
# Misclassified 46 of 296 points | MCR = 0.1554054054054054
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.404100
# 0       hhsize    0.191082
# 7     prod_idx    0.121499
# 6    lvstk_idx    0.112770
# 2      rec_age    0.089257
#
# Trial #10:
# Misclassified 53 of 296 points | MCR = 0.17905405405405406
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.404253
# 0       hhsize    0.169225
# 2      rec_age    0.152906
# 7     prod_idx    0.138858
# 6    lvstk_idx    0.045406
#
# Trial #11:
# Misclassified 55 of 296 points | MCR = 0.1858108108108108
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.315404
# 5     asst_idx    0.311701
# 0       hhsize    0.145329
# 2      rec_age    0.108786
# 8  any_savings    0.042955
#
# Trial #12:
# Misclassified 45 of 296 points | MCR = 0.15202702702702703
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.309706
# 0       hhsize    0.205388
# 7     prod_idx    0.171651
# 2      rec_age    0.167560
# 6    lvstk_idx    0.067093
#
# Trial #13:
# Misclassified 48 of 296 points | MCR = 0.16216216216216217
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.286249
# 0       hhsize    0.222686
# 7     prod_idx    0.186226
# 2      rec_age    0.128533
# 3     imp_dich    0.082525
#
# Trial #14:
# Misclassified 59 of 296 points | MCR = 0.19932432432432431
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.336588
# 2      rec_age    0.184957
# 0       hhsize    0.169030
# 6    lvstk_idx    0.144138
# 7     prod_idx    0.082507
#
# Trial #15:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.241845
# 5     asst_idx    0.206633
# 6    lvstk_idx    0.166401
# 0       hhsize    0.139842
# 2      rec_age    0.101301
#
# Trial #16:
# Misclassified 44 of 296 points | MCR = 0.14864864864864866
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.355820
# 7     prod_idx    0.140881
# 0       hhsize    0.128952
# 2      rec_age    0.118155
# 6    lvstk_idx    0.092941
#
# Trial #17:
# Misclassified 70 of 296 points | MCR = 0.23648648648648649
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.440895
# 0       hhsize    0.148786
# 2      rec_age    0.126934
# 7     prod_idx    0.100586
# 6    lvstk_idx    0.054874
#
# Trial #18:
# Misclassified 42 of 296 points | MCR = 0.14189189189189189
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.283880
# 0       hhsize    0.200713
# 2      rec_age    0.179385
# 6    lvstk_idx    0.157492
# 7     prod_idx    0.084198
#
# Trial #19:
# Misclassified 50 of 296 points | MCR = 0.16891891891891891
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.292495
# 0       hhsize    0.183321
# 7     prod_idx    0.178671
# 6    lvstk_idx    0.151718
# 2      rec_age    0.105566
#
# Trial #20:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.301597
# 0       hhsize    0.178134
# 2      rec_age    0.151197
# 7     prod_idx    0.140221
# 6    lvstk_idx    0.112301
#
# Trial #21:
# Misclassified 50 of 296 points | MCR = 0.16891891891891891
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.311314
# 0       hhsize    0.179466
# 2      rec_age    0.159704
# 7     prod_idx    0.145510
# 6    lvstk_idx    0.118021
#
# Trial #22:
# Misclassified 54 of 296 points | MCR = 0.18243243243243243
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.258576
# 0       hhsize    0.229125
# 2      rec_age    0.183398
# 5     asst_idx    0.175789
# 6    lvstk_idx    0.090313
#
# Trial #23:
# Misclassified 49 of 296 points | MCR = 0.16554054054054054
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.284009
# 7     prod_idx    0.233145
# 0       hhsize    0.190492
# 2      rec_age    0.140970
# 6    lvstk_idx    0.068386
#
# Trial #24:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.266902
# 2      rec_age    0.200981
# 0       hhsize    0.198423
# 6    lvstk_idx    0.154078
# 7     prod_idx    0.092400
#
# Trial #25:
# Misclassified 43 of 296 points | MCR = 0.14527027027027026
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.328846
# 7     prod_idx    0.250517
# 0       hhsize    0.133268
# 1         able    0.093605
# 6    lvstk_idx    0.083504
#
# Trial #26:
# Misclassified 61 of 296 points | MCR = 0.20608108108108109
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.325518
# 0       hhsize    0.249671
# 7     prod_idx    0.129100
# 6    lvstk_idx    0.101713
# 2      rec_age    0.062077
#
# Trial #27:
# Misclassified 53 of 296 points | MCR = 0.17905405405405406
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.281747
# 7     prod_idx    0.176190
# 2      rec_age    0.147798
# 6    lvstk_idx    0.133414
# 0       hhsize    0.103882
#
# Trial #28:
# Misclassified 49 of 296 points | MCR = 0.16554054054054054
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.318257
# 7     prod_idx    0.190218
# 6    lvstk_idx    0.145104
# 0       hhsize    0.133435
# 2      rec_age    0.086600
#
# Trial #29:
# Misclassified 47 of 296 points | MCR = 0.15878378378378377
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.328024
# 0       hhsize    0.214570
# 7     prod_idx    0.140001
# 2      rec_age    0.116880
# 6    lvstk_idx    0.087242
#
# Trial #30:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.273875
# 6    lvstk_idx    0.189718
# 7     prod_idx    0.181352
# 0       hhsize    0.156816
# 1         able    0.091233
#
# Trial #31:
# Misclassified 43 of 296 points | MCR = 0.14527027027027026
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.238683
# 7     prod_idx    0.182114
# 2      rec_age    0.155774
# 6    lvstk_idx    0.146520
# 0       hhsize    0.139874
#
# Trial #32:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.366939
# 7     prod_idx    0.188296
# 0       hhsize    0.168859
# 2      rec_age    0.151077
# 6    lvstk_idx    0.068922
#
# Trial #33:
# Misclassified 49 of 296 points | MCR = 0.16554054054054054
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.267701
# 6    lvstk_idx    0.187990
# 0       hhsize    0.179329
# 2      rec_age    0.143660
# 7     prod_idx    0.128809
#
# Trial #34:
# Misclassified 47 of 296 points | MCR = 0.15878378378378377
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.272099
# 2      rec_age    0.227055
# 5     asst_idx    0.219548
# 0       hhsize    0.095398
# 1         able    0.068827
#
# Trial #35:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.289550
# 0       hhsize    0.201195
# 6    lvstk_idx    0.150656
# 2      rec_age    0.128273
# 7     prod_idx    0.091266
#
# Trial #36:
# Misclassified 40 of 296 points | MCR = 0.13513513513513514
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.230497
# 6    lvstk_idx    0.153283
# 2      rec_age    0.135371
# 7     prod_idx    0.128180
# 0       hhsize    0.127389
#
# Trial #37:
# Misclassified 62 of 296 points | MCR = 0.20945945945945946
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.337710
# 0       hhsize    0.179442
# 6    lvstk_idx    0.142823
# 7     prod_idx    0.141371
# 2      rec_age    0.102550
#
# Trial #38:
# Misclassified 49 of 296 points | MCR = 0.16554054054054054
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.248014
# 0       hhsize    0.246702
# 7     prod_idx    0.203780
# 2      rec_age    0.163383
# 8  any_savings    0.061806
#
# Trial #39:
# Misclassified 43 of 296 points | MCR = 0.14527027027027026
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.379684
# 2      rec_age    0.144230
# 1         able    0.143062
# 7     prod_idx    0.112215
# 0       hhsize    0.103871
#
# Trial #40:
# Misclassified 37 of 296 points | MCR = 0.125
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.291734
# 7     prod_idx    0.137343
# 1         able    0.136329
# 2      rec_age    0.132458
# 0       hhsize    0.112004
#
# Trial #41:
# Misclassified 52 of 296 points | MCR = 0.17567567567567569
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.256123
# 0       hhsize    0.210201
# 7     prod_idx    0.165499
# 2      rec_age    0.161556
# 6    lvstk_idx    0.102439
#
# Trial #42:
# Misclassified 35 of 296 points | MCR = 0.11824324324324324
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.229581
# 0       hhsize    0.161874
# 6    lvstk_idx    0.158053
# 2      rec_age    0.153341
# 7     prod_idx    0.149405
#
# Trial #43:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.338388
# 2      rec_age    0.156078
# 6    lvstk_idx    0.155210
# 0       hhsize    0.142905
# 1         able    0.092451
#
# Trial #44:
# Misclassified 50 of 296 points | MCR = 0.16891891891891891
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.248262
# 7     prod_idx    0.222784
# 2      rec_age    0.192081
# 0       hhsize    0.130543
# 6    lvstk_idx    0.103049
#
# Trial #45:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.378166
# 7     prod_idx    0.144829
# 2      rec_age    0.144338
# 0       hhsize    0.138631
# 6    lvstk_idx    0.093084
#
# Trial #46:
# Misclassified 55 of 296 points | MCR = 0.1858108108108108
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.334424
# 7     prod_idx    0.179910
# 0       hhsize    0.172222
# 2      rec_age    0.170579
# 6    lvstk_idx    0.093434
#
# Trial #47:
# Misclassified 51 of 296 points | MCR = 0.17229729729729729
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.338633
# 0       hhsize    0.215999
# 2      rec_age    0.118466
# 6    lvstk_idx    0.113734
# 7     prod_idx    0.098929
#
# Trial #48:
# Misclassified 46 of 296 points | MCR = 0.1554054054054054
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.221908
# 5     asst_idx    0.220586
# 0       hhsize    0.184939
# 2      rec_age    0.138751
# 6    lvstk_idx    0.090585
#
# Trial #49:
# Misclassified 52 of 296 points | MCR = 0.17567567567567569
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.241155
# 0       hhsize    0.217019
# 5     asst_idx    0.195787
# 6    lvstk_idx    0.151463
# 2      rec_age    0.141367
#
# Trial #50:
# Misclassified 49 of 296 points | MCR = 0.16554054054054054
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.298336
# 2      rec_age    0.162306
# 7     prod_idx    0.142584
# 6    lvstk_idx    0.125016
# 0       hhsize    0.102024

# %% [markdown]
# ### `HF3` as label

# %%
# Fit a basic classification tree to the baseline data with HF3 as labels

features = baseline[[
    "hhsize", "able", "rec_age", "imp_dich", "future1yr",
    "asst_idx", "lvstk_idx", "prod_idx", "any_savings"]]

labels = baseline["HF3"]

train_test_eval(features, labels, "baseline_hf3")
# Out:
# Trial #1:
# Misclassified 121 of 296 points | MCR = 0.40878378378378377
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.243303
# 2      rec_age    0.177953
# 0       hhsize    0.160470
# 5     asst_idx    0.149932
# 6    lvstk_idx    0.148729
#
# Trial #2:
# Misclassified 112 of 296 points | MCR = 0.3783783783783784
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.227107
# 5     asst_idx    0.225497
# 6    lvstk_idx    0.158134
# 2      rec_age    0.157729
# 0       hhsize    0.097379
#
# Trial #3:
# Misclassified 104 of 296 points | MCR = 0.35135135135135137
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.233667
# 2      rec_age    0.215337
# 7     prod_idx    0.199209
# 6    lvstk_idx    0.112196
# 0       hhsize    0.096461
#
# Trial #4:
# Misclassified 114 of 296 points | MCR = 0.38513513513513514
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.285002
# 7     prod_idx    0.258489
# 2      rec_age    0.175250
# 6    lvstk_idx    0.089821
# 0       hhsize    0.076808
#
# Trial #5:
# Misclassified 111 of 296 points | MCR = 0.375
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.285791
# 2      rec_age    0.205187
# 5     asst_idx    0.168043
# 0       hhsize    0.118282
# 6    lvstk_idx    0.115088
#
# Trial #6:
# Misclassified 102 of 296 points | MCR = 0.34459459459459457
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.263541
# 5     asst_idx    0.213501
# 2      rec_age    0.195168
# 0       hhsize    0.123251
# 6    lvstk_idx    0.097542
#
# Trial #7:
# Misclassified 116 of 296 points | MCR = 0.3918918918918919
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.231558
# 7     prod_idx    0.197229
# 2      rec_age    0.170831
# 0       hhsize    0.154505
# 6    lvstk_idx    0.086703
#
# Trial #8:
# Misclassified 103 of 296 points | MCR = 0.34797297297297297
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.289296
# 5     asst_idx    0.211496
# 2      rec_age    0.175650
# 0       hhsize    0.116343
# 1         able    0.078575
#
# Trial #9:
# Misclassified 105 of 296 points | MCR = 0.3547297297297297
# Five most useful features:
#   feature_name  importance
# 2      rec_age    0.261177
# 5     asst_idx    0.188789
# 7     prod_idx    0.156559
# 0       hhsize    0.144064
# 6    lvstk_idx    0.130366
#
# Trial #10:
# Misclassified 108 of 296 points | MCR = 0.36486486486486486
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.289322
# 5     asst_idx    0.200894
# 2      rec_age    0.154366
# 6    lvstk_idx    0.112295
# 0       hhsize    0.083493
#
# Trial #11:
# Misclassified 119 of 296 points | MCR = 0.40202702702702703
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.213263
# 5     asst_idx    0.211444
# 0       hhsize    0.144408
# 2      rec_age    0.143434
# 6    lvstk_idx    0.123978
#
# Trial #12:
# Misclassified 120 of 296 points | MCR = 0.40540540540540543
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.247088
# 7     prod_idx    0.230402
# 6    lvstk_idx    0.142028
# 2      rec_age    0.138436
# 0       hhsize    0.116186
#
# Trial #13:
# Misclassified 108 of 296 points | MCR = 0.36486486486486486
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.194056
# 7     prod_idx    0.175580
# 6    lvstk_idx    0.174100
# 0       hhsize    0.157735
# 2      rec_age    0.137673
#
# Trial #14:
# Misclassified 105 of 296 points | MCR = 0.3547297297297297
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.264902
# 2      rec_age    0.223414
# 7     prod_idx    0.174009
# 6    lvstk_idx    0.134929
# 1         able    0.067407
#
# Trial #15:
# Misclassified 103 of 296 points | MCR = 0.34797297297297297
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.241508
# 7     prod_idx    0.198516
# 2      rec_age    0.161924
# 6    lvstk_idx    0.130541
# 0       hhsize    0.130098
#
# Trial #16:
# Misclassified 109 of 296 points | MCR = 0.36824324324324326
# Five most useful features:
#   feature_name  importance
# 2      rec_age    0.219391
# 7     prod_idx    0.187834
# 6    lvstk_idx    0.181236
# 5     asst_idx    0.160570
# 1         able    0.120193
#
# Trial #17:
# Misclassified 117 of 296 points | MCR = 0.3952702702702703
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.246878
# 2      rec_age    0.225922
# 5     asst_idx    0.146984
# 6    lvstk_idx    0.118408
# 0       hhsize    0.109777
#
# Trial #18:
# Misclassified 116 of 296 points | MCR = 0.3918918918918919
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.227656
# 2      rec_age    0.187023
# 5     asst_idx    0.139405
# 6    lvstk_idx    0.136391
# 0       hhsize    0.130641
#
# Trial #19:
# Misclassified 111 of 296 points | MCR = 0.375
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.248995
# 7     prod_idx    0.234821
# 2      rec_age    0.197114
# 0       hhsize    0.110478
# 1         able    0.080371
#
# Trial #20:
# Misclassified 116 of 296 points | MCR = 0.3918918918918919
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.254186
# 2      rec_age    0.189821
# 5     asst_idx    0.149465
# 6    lvstk_idx    0.127726
# 1         able    0.101067
#
# Trial #21:
# Misclassified 120 of 296 points | MCR = 0.40540540540540543
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.260031
# 7     prod_idx    0.232435
# 2      rec_age    0.153808
# 6    lvstk_idx    0.144447
# 0       hhsize    0.074221
#
# Trial #22:
# Misclassified 113 of 296 points | MCR = 0.38175675675675674
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.265188
# 5     asst_idx    0.207081
# 2      rec_age    0.151583
# 6    lvstk_idx    0.122127
# 0       hhsize    0.103980
#
# Trial #23:
# Misclassified 106 of 296 points | MCR = 0.3581081081081081
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.262267
# 5     asst_idx    0.206711
# 2      rec_age    0.145025
# 6    lvstk_idx    0.129863
# 0       hhsize    0.093073
#
# Trial #24:
# Misclassified 103 of 296 points | MCR = 0.34797297297297297
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.251780
# 5     asst_idx    0.243570
# 2      rec_age    0.157370
# 0       hhsize    0.102131
# 6    lvstk_idx    0.084073
#
# Trial #25:
# Misclassified 106 of 296 points | MCR = 0.3581081081081081
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.236974
# 7     prod_idx    0.177652
# 0       hhsize    0.177197
# 2      rec_age    0.136737
# 6    lvstk_idx    0.100620
#
# Trial #26:
# Misclassified 116 of 296 points | MCR = 0.3918918918918919
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.224432
# 5     asst_idx    0.176884
# 0       hhsize    0.172108
# 2      rec_age    0.134337
# 6    lvstk_idx    0.088512
#
# Trial #27:
# Misclassified 110 of 296 points | MCR = 0.3716216216216216
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.250751
# 2      rec_age    0.238131
# 5     asst_idx    0.128280
# 6    lvstk_idx    0.127945
# 0       hhsize    0.077528
#
# Trial #28:
# Misclassified 121 of 296 points | MCR = 0.40878378378378377
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.206605
# 5     asst_idx    0.202457
# 6    lvstk_idx    0.147961
# 2      rec_age    0.138463
# 0       hhsize    0.131101
#
# Trial #29:
# Misclassified 113 of 296 points | MCR = 0.38175675675675674
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.250274
# 5     asst_idx    0.197321
# 2      rec_age    0.196515
# 0       hhsize    0.142558
# 6    lvstk_idx    0.110995
#
# Trial #30:
# Misclassified 105 of 296 points | MCR = 0.3547297297297297
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.242760
# 5     asst_idx    0.237980
# 2      rec_age    0.209620
# 6    lvstk_idx    0.086253
# 0       hhsize    0.068360
#
# Trial #31:
# Misclassified 121 of 296 points | MCR = 0.40878378378378377
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.217284
# 2      rec_age    0.183012
# 5     asst_idx    0.178967
# 6    lvstk_idx    0.177877
# 0       hhsize    0.113451
#
# Trial #32:
# Misclassified 123 of 296 points | MCR = 0.4155405405405405
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.257843
# 5     asst_idx    0.226473
# 2      rec_age    0.164592
# 6    lvstk_idx    0.119078
# 0       hhsize    0.097784
#
# Trial #33:
# Misclassified 107 of 296 points | MCR = 0.3614864864864865
# Five most useful features:
#   feature_name  importance
# 2      rec_age    0.233426
# 5     asst_idx    0.177911
# 7     prod_idx    0.175451
# 6    lvstk_idx    0.143986
# 0       hhsize    0.098649
#
# Trial #34:
# Misclassified 115 of 296 points | MCR = 0.3885135135135135
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.206439
# 7     prod_idx    0.201929
# 0       hhsize    0.163151
# 2      rec_age    0.162577
# 6    lvstk_idx    0.121007
#
# Trial #35:
# Misclassified 112 of 296 points | MCR = 0.3783783783783784
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.250077
# 7     prod_idx    0.213525
# 2      rec_age    0.191770
# 0       hhsize    0.121404
# 6    lvstk_idx    0.068690
#
# Trial #36:
# Misclassified 104 of 296 points | MCR = 0.35135135135135137
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.247820
# 2      rec_age    0.180650
# 6    lvstk_idx    0.169521
# 0       hhsize    0.160956
# 5     asst_idx    0.110100
#
# Trial #37:
# Misclassified 111 of 296 points | MCR = 0.375
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.268056
# 2      rec_age    0.193017
# 5     asst_idx    0.189946
# 0       hhsize    0.110563
# 6    lvstk_idx    0.071747
#
# Trial #38:
# Misclassified 114 of 296 points | MCR = 0.38513513513513514
# Five most useful features:
#   feature_name  importance
# 2      rec_age    0.221751
# 7     prod_idx    0.213136
# 5     asst_idx    0.162608
# 6    lvstk_idx    0.124108
# 0       hhsize    0.092330
#
# Trial #39:
# Misclassified 117 of 296 points | MCR = 0.3952702702702703
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.229512
# 5     asst_idx    0.208579
# 2      rec_age    0.183986
# 0       hhsize    0.137984
# 6    lvstk_idx    0.109168
#
# Trial #40:
# Misclassified 118 of 296 points | MCR = 0.39864864864864863
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.247967
# 5     asst_idx    0.229727
# 2      rec_age    0.153488
# 6    lvstk_idx    0.122389
# 0       hhsize    0.101845
#
# Trial #41:
# Misclassified 126 of 296 points | MCR = 0.42567567567567566
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.247409
# 7     prod_idx    0.231510
# 2      rec_age    0.183819
# 6    lvstk_idx    0.117088
# 0       hhsize    0.114284
#
# Trial #42:
# Misclassified 103 of 296 points | MCR = 0.34797297297297297
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.244091
# 2      rec_age    0.188500
# 7     prod_idx    0.156712
# 6    lvstk_idx    0.120310
# 0       hhsize    0.110929
# Trial #43:
# Misclassified 117 of 296 points | MCR = 0.3952702702702703
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.233762
# 2      rec_age    0.193155
# 6    lvstk_idx    0.146445
# 5     asst_idx    0.136881
# 0       hhsize    0.123710
#
# Trial #44:
# Misclassified 112 of 296 points | MCR = 0.3783783783783784
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.231290
# 5     asst_idx    0.201793
# 6    lvstk_idx    0.194844
# 2      rec_age    0.121563
# 0       hhsize    0.088608
#
# Trial #45:
# Misclassified 103 of 296 points | MCR = 0.34797297297297297
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.240502
# 2      rec_age    0.220302
# 5     asst_idx    0.211370
# 6    lvstk_idx    0.104523
# 1         able    0.073844
#
# Trial #46:
# Misclassified 100 of 296 points | MCR = 0.33783783783783783
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.255399
# 5     asst_idx    0.219948
# 0       hhsize    0.153857
# 6    lvstk_idx    0.151695
# 2      rec_age    0.085518
#
# Trial #47:
# Misclassified 109 of 296 points | MCR = 0.36824324324324326
# Five most useful features:
#   feature_name  importance
# 5     asst_idx    0.200724
# 2      rec_age    0.199033
# 6    lvstk_idx    0.179199
# 7     prod_idx    0.158069
# 0       hhsize    0.128113
#
# Trial #48:
# Misclassified 116 of 296 points | MCR = 0.3918918918918919
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.259645
# 2      rec_age    0.202412
# 5     asst_idx    0.174571
# 0       hhsize    0.142516
# 6    lvstk_idx    0.093611
#
# Trial #49:
# Misclassified 113 of 296 points | MCR = 0.38175675675675674
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.256503
# 5     asst_idx    0.208275
# 2      rec_age    0.139347
# 6    lvstk_idx    0.123211
# 0       hhsize    0.114850
#
# Trial #50:
# Misclassified 111 of 296 points | MCR = 0.375
# Five most useful features:
#   feature_name  importance
# 7     prod_idx    0.274819
# 2      rec_age    0.242617
# 5     asst_idx    0.140588
# 6    lvstk_idx    0.119470
# 0       hhsize    0.098919

# %% [markdown]
# ## `denver.csv` data

# %%
# Data cleaning

# Some rows have NAs
denver = pd.read_csv("data/denver.csv")
denver.dropna(axis="index", how="any", inplace=True)
denver.reset_index(inplace=True)
denver.drop(axis="columns", labels=["index"], inplace=True)

# %% [markdown]
# ### `HF2` as labels

# %%
# Fit a basic classification tree to the denver data with HF2 as labels

features = denver[[
    "asst_idx_z", "lvstk_idx_z", "prod_idx_z", "hrv_value_z",
    "LGhrv_value_z", "exp_total_ap_z", "LGnfe_rev_z",
    "nfe_z", "inc_rev_idxSD_z", "fin_debt_idxSD_z"]]

labels = denver["HF2"]

train_test_eval(features, labels, "denver_hf2")
# Out:
# Trial #1:
# Misclassified 49 of 304 points | MCR = 0.1611842105263158
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.214261
# 0        asst_idx_z    0.192481
# 8   inc_rev_idxSD_z    0.150251
# 3       hrv_value_z    0.125661
# 9  fin_debt_idxSD_z    0.100745
#
# Trial #2:
# Misclassified 52 of 304 points | MCR = 0.17105263157894737
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.287564
# 9  fin_debt_idxSD_z    0.164221
# 2        prod_idx_z    0.140275
# 1       lvstk_idx_z    0.111712
# 8   inc_rev_idxSD_z    0.087696
#
# Trial #3:
# Misclassified 54 of 304 points | MCR = 0.17763157894736842
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.271410
# 2        prod_idx_z    0.235635
# 8   inc_rev_idxSD_z    0.127031
# 0        asst_idx_z    0.116393
# 4     LGhrv_value_z    0.059805
#
# Trial #4:
# Misclassified 52 of 304 points | MCR = 0.17105263157894737
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.329545
# 8   inc_rev_idxSD_z    0.218663
# 9  fin_debt_idxSD_z    0.140061
# 4     LGhrv_value_z    0.098460
# 6       LGnfe_rev_z    0.081810
#
# Trial #5:
# Misclassified 53 of 304 points | MCR = 0.17434210526315788
# Five most useful features:
#        feature_name  importance
# 1       lvstk_idx_z    0.171112
# 2        prod_idx_z    0.166670
# 0        asst_idx_z    0.153620
# 9  fin_debt_idxSD_z    0.127635
# 6       LGnfe_rev_z    0.084697
#
# Trial #6:
# Misclassified 47 of 304 points | MCR = 0.15460526315789475
# Five most useful features:
#       feature_name  importance
# 2       prod_idx_z    0.154390
# 6      LGnfe_rev_z    0.151811
# 0       asst_idx_z    0.146798
# 8  inc_rev_idxSD_z    0.124505
# 1      lvstk_idx_z    0.122627
#
# Trial #7:
# Misclassified 54 of 304 points | MCR = 0.17763157894736842
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.299890
# 9  fin_debt_idxSD_z    0.177793
# 6       LGnfe_rev_z    0.101455
# 2        prod_idx_z    0.097486
# 8   inc_rev_idxSD_z    0.095770
#
# Trial #8:
# Misclassified 54 of 304 points | MCR = 0.17763157894736842
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.250752
# 9  fin_debt_idxSD_z    0.154502
# 8   inc_rev_idxSD_z    0.139115
# 4     LGhrv_value_z    0.135825
# 1       lvstk_idx_z    0.108231
#
# Trial #9:
# Misclassified 44 of 304 points | MCR = 0.14473684210526316
# Five most useful features:
#       feature_name  importance
# 0       asst_idx_z    0.226843
# 8  inc_rev_idxSD_z    0.175426
# 2       prod_idx_z    0.134051
# 6      LGnfe_rev_z    0.116724
# 1      lvstk_idx_z    0.091288
#
# Trial #10:
# Misclassified 54 of 304 points | MCR = 0.17763157894736842
# Five most useful features:
#       feature_name  importance
# 0       asst_idx_z    0.307716
# 8  inc_rev_idxSD_z    0.162016
# 3      hrv_value_z    0.121535
# 4    LGhrv_value_z    0.086949
# 2       prod_idx_z    0.079725
#
# Trial #11:
# Misclassified 53 of 304 points | MCR = 0.17434210526315788
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.190966
# 9  fin_debt_idxSD_z    0.184225
# 2        prod_idx_z    0.122604
# 1       lvstk_idx_z    0.119885
# 3       hrv_value_z    0.118889
#
# Trial #12:
# Misclassified 52 of 304 points | MCR = 0.17105263157894737
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.214631
# 0        asst_idx_z    0.203762
# 9  fin_debt_idxSD_z    0.156249
# 1       lvstk_idx_z    0.104471
# 8   inc_rev_idxSD_z    0.098183
#
# Trial #13:
# Misclassified 45 of 304 points | MCR = 0.14802631578947367
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.258469
# 9  fin_debt_idxSD_z    0.202898
# 2        prod_idx_z    0.147428
# 8   inc_rev_idxSD_z    0.127153
# 1       lvstk_idx_z    0.117259
#
# Trial #14:
# Misclassified 57 of 304 points | MCR = 0.1875
# Five most useful features:
#        feature_name  importance
# 8   inc_rev_idxSD_z    0.256434
# 0        asst_idx_z    0.239200
# 9  fin_debt_idxSD_z    0.129847
# 2        prod_idx_z    0.120860
# 4     LGhrv_value_z    0.084926
#
# Trial #15:
# Misclassified 51 of 304 points | MCR = 0.16776315789473684
# Five most useful features:
#       feature_name  importance
# 2       prod_idx_z    0.220195
# 0       asst_idx_z    0.169166
# 8  inc_rev_idxSD_z    0.158668
# 1      lvstk_idx_z    0.119641
# 6      LGnfe_rev_z    0.119512
#
# Trial #16:
# Misclassified 58 of 304 points | MCR = 0.19078947368421054
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.246348
# 0        asst_idx_z    0.220471
# 8   inc_rev_idxSD_z    0.152201
# 9  fin_debt_idxSD_z    0.122229
# 1       lvstk_idx_z    0.091722
#
# Trial #17:
# Misclassified 50 of 304 points | MCR = 0.16447368421052633
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.250819
# 9  fin_debt_idxSD_z    0.151334
# 2        prod_idx_z    0.144899
# 6       LGnfe_rev_z    0.138245
# 8   inc_rev_idxSD_z    0.091335
#
# Trial #18:
# Misclassified 51 of 304 points | MCR = 0.16776315789473684
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.240743
# 2        prod_idx_z    0.204285
# 1       lvstk_idx_z    0.140993
# 0        asst_idx_z    0.126613
# 6       LGnfe_rev_z    0.112027
#
# Trial #19:
# Misclassified 52 of 304 points | MCR = 0.17105263157894737
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.287256
# 8   inc_rev_idxSD_z    0.185384
# 2        prod_idx_z    0.125548
# 9  fin_debt_idxSD_z    0.102855
# 1       lvstk_idx_z    0.099419
#
# Trial #20:
# Misclassified 64 of 304 points | MCR = 0.21052631578947367
# Five most useful features:
#        feature_name  importance
# 6       LGnfe_rev_z    0.177982
# 9  fin_debt_idxSD_z    0.147000
# 2        prod_idx_z    0.138269
# 8   inc_rev_idxSD_z    0.137985
# 0        asst_idx_z    0.119489
#
# Trial #21:
# Misclassified 54 of 304 points | MCR = 0.17763157894736842
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.234031
# 8   inc_rev_idxSD_z    0.203681
# 9  fin_debt_idxSD_z    0.132042
# 1       lvstk_idx_z    0.118527
# 0        asst_idx_z    0.114756
#
# Trial #22:
# Misclassified 49 of 304 points | MCR = 0.1611842105263158
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.220699
# 2        prod_idx_z    0.206498
# 8   inc_rev_idxSD_z    0.194125
# 9  fin_debt_idxSD_z    0.099285
# 1       lvstk_idx_z    0.075137
#
# Trial #23:
# Misclassified 49 of 304 points | MCR = 0.1611842105263158
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.215315
# 0        asst_idx_z    0.185717
# 2        prod_idx_z    0.133763
# 8   inc_rev_idxSD_z    0.102204
# 1       lvstk_idx_z    0.091697
#
# Trial #24:
# Misclassified 50 of 304 points | MCR = 0.16447368421052633
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.222215
# 2        prod_idx_z    0.195376
# 9  fin_debt_idxSD_z    0.179907
# 8   inc_rev_idxSD_z    0.114406
# 3       hrv_value_z    0.067069
#
# Trial #25:
# Misclassified 52 of 304 points | MCR = 0.17105263157894737
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.247854
# 8   inc_rev_idxSD_z    0.191868
# 9  fin_debt_idxSD_z    0.187338
# 2        prod_idx_z    0.113686
# 1       lvstk_idx_z    0.057015
#
# Trial #26:
# Misclassified 49 of 304 points | MCR = 0.1611842105263158
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.186101
# 2        prod_idx_z    0.178345
# 8   inc_rev_idxSD_z    0.166890
# 9  fin_debt_idxSD_z    0.144956
# 1       lvstk_idx_z    0.140775
#
# Trial #27:
# Misclassified 42 of 304 points | MCR = 0.13815789473684212
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.247784
# 8   inc_rev_idxSD_z    0.242308
# 0        asst_idx_z    0.117299
# 4     LGhrv_value_z    0.104525
# 9  fin_debt_idxSD_z    0.099600
#
# Trial #28:
# Misclassified 57 of 304 points | MCR = 0.1875
# Five most useful features:
#       feature_name  importance
# 0       asst_idx_z    0.200385
# 2       prod_idx_z    0.192260
# 8  inc_rev_idxSD_z    0.155596
# 1      lvstk_idx_z    0.101209
# 3      hrv_value_z    0.098063
#
# Trial #29:
# Misclassified 57 of 304 points | MCR = 0.1875
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.269954
# 0        asst_idx_z    0.236775
# 8   inc_rev_idxSD_z    0.189019
# 2        prod_idx_z    0.090481
# 3       hrv_value_z    0.085496
#
# Trial #30:
# Misclassified 50 of 304 points | MCR = 0.16447368421052633
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.254083
# 8   inc_rev_idxSD_z    0.170574
# 1       lvstk_idx_z    0.165033
# 9  fin_debt_idxSD_z    0.161175
# 2        prod_idx_z    0.110042
#
# Trial #31:
# Misclassified 50 of 304 points | MCR = 0.16447368421052633
# Five most useful features:
#       feature_name  importance
# 0       asst_idx_z    0.184451
# 2       prod_idx_z    0.163022
# 1      lvstk_idx_z    0.134813
# 8  inc_rev_idxSD_z    0.129601
# 6      LGnfe_rev_z    0.111789
#
# Trial #32:
# Misclassified 55 of 304 points | MCR = 0.18092105263157895
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.198024
# 2        prod_idx_z    0.190634
# 1       lvstk_idx_z    0.165421
# 9  fin_debt_idxSD_z    0.137451
# 3       hrv_value_z    0.112809
#
# Trial #33:
# Misclassified 47 of 304 points | MCR = 0.15460526315789475
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.347683
# 2        prod_idx_z    0.213647
# 8   inc_rev_idxSD_z    0.160384
# 9  fin_debt_idxSD_z    0.090777
# 4     LGhrv_value_z    0.069088
#
# Trial #34:
# Misclassified 45 of 304 points | MCR = 0.14802631578947367
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.230988
# 9  fin_debt_idxSD_z    0.174977
# 8   inc_rev_idxSD_z    0.127882
# 2        prod_idx_z    0.114784
# 4     LGhrv_value_z    0.110938
#
# Trial #35:
# Misclassified 53 of 304 points | MCR = 0.17434210526315788
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.380799
# 8   inc_rev_idxSD_z    0.173350
# 4     LGhrv_value_z    0.149454
# 1       lvstk_idx_z    0.104272
# 9  fin_debt_idxSD_z    0.068449
#
# Trial #36:
# Misclassified 47 of 304 points | MCR = 0.15460526315789475
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.214205
# 9  fin_debt_idxSD_z    0.177326
# 2        prod_idx_z    0.155099
# 8   inc_rev_idxSD_z    0.129650
# 1       lvstk_idx_z    0.096926
#
# Trial #37:
# Misclassified 50 of 304 points | MCR = 0.16447368421052633
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.314156
# 2        prod_idx_z    0.159410
# 8   inc_rev_idxSD_z    0.144420
# 9  fin_debt_idxSD_z    0.126070
# 6       LGnfe_rev_z    0.080007
#
# Trial #38:
# Misclassified 56 of 304 points | MCR = 0.18421052631578946
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.186075
# 9  fin_debt_idxSD_z    0.153331
# 1       lvstk_idx_z    0.150181
# 8   inc_rev_idxSD_z    0.149343
# 2        prod_idx_z    0.138442
#
# Trial #39:
# Misclassified 50 of 304 points | MCR = 0.16447368421052633
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.201089
# 2        prod_idx_z    0.185024
# 8   inc_rev_idxSD_z    0.184689
# 1       lvstk_idx_z    0.169525
# 9  fin_debt_idxSD_z    0.073588
#
# Trial #40:
# Misclassified 47 of 304 points | MCR = 0.15460526315789475
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.257720
# 2        prod_idx_z    0.185680
# 8   inc_rev_idxSD_z    0.175150
# 0        asst_idx_z    0.155645
# 6       LGnfe_rev_z    0.114096
#
# Trial #41:
# Misclassified 52 of 304 points | MCR = 0.17105263157894737
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.253228
# 8   inc_rev_idxSD_z    0.168589
# 2        prod_idx_z    0.160122
# 6       LGnfe_rev_z    0.124064
# 4     LGhrv_value_z    0.115965
#
# Trial #42:
# Misclassified 42 of 304 points | MCR = 0.13815789473684212
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.333243
# 8   inc_rev_idxSD_z    0.194520
# 9  fin_debt_idxSD_z    0.171831
# 2        prod_idx_z    0.095110
# 4     LGhrv_value_z    0.054205
# Trial #43:
# Misclassified 47 of 304 points | MCR = 0.15460526315789475
# Five most useful features:
#        feature_name  importance
# 8   inc_rev_idxSD_z    0.199497
# 2        prod_idx_z    0.184385
# 0        asst_idx_z    0.184367
# 9  fin_debt_idxSD_z    0.143491
# 3       hrv_value_z    0.135111
#
# Trial #44:
# Misclassified 47 of 304 points | MCR = 0.15460526315789475
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.282731
# 9  fin_debt_idxSD_z    0.144126
# 8   inc_rev_idxSD_z    0.139599
# 4     LGhrv_value_z    0.119746
# 3       hrv_value_z    0.081907
#
# Trial #45:
# Misclassified 51 of 304 points | MCR = 0.16776315789473684
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.325945
# 1       lvstk_idx_z    0.128719
# 8   inc_rev_idxSD_z    0.124764
# 9  fin_debt_idxSD_z    0.116493
# 4     LGhrv_value_z    0.091596
#
# Trial #46:
# Misclassified 64 of 304 points | MCR = 0.21052631578947367
# Five most useful features:
#       feature_name  importance
# 0       asst_idx_z    0.306461
# 8  inc_rev_idxSD_z    0.193916
# 2       prod_idx_z    0.143215
# 1      lvstk_idx_z    0.098957
# 3      hrv_value_z    0.094578
#
# Trial #47:
# Misclassified 49 of 304 points | MCR = 0.1611842105263158
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.267150
# 0        asst_idx_z    0.224974
# 9  fin_debt_idxSD_z    0.202718
# 8   inc_rev_idxSD_z    0.137379
# 4     LGhrv_value_z    0.051720
#
# Trial #48:
# Misclassified 48 of 304 points | MCR = 0.15789473684210525
# Five most useful features:
#        feature_name  importance
# 8   inc_rev_idxSD_z    0.191188
# 0        asst_idx_z    0.179767
# 9  fin_debt_idxSD_z    0.146485
# 2        prod_idx_z    0.141648
# 1       lvstk_idx_z    0.111575
#
# Trial #49:
# Misclassified 55 of 304 points | MCR = 0.18092105263157895
# Five most useful features:
#        feature_name  importance
# 8   inc_rev_idxSD_z    0.285124
# 0        asst_idx_z    0.257328
# 2        prod_idx_z    0.148267
# 9  fin_debt_idxSD_z    0.099951
# 4     LGhrv_value_z    0.067819
#
# Trial #50:
# Misclassified 52 of 304 points | MCR = 0.17105263157894737
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.211219
# 0        asst_idx_z    0.189782
# 8   inc_rev_idxSD_z    0.145346
# 1       lvstk_idx_z    0.131168
# 2        prod_idx_z    0.118405

# %% [markdown]
# ### `HF3` as labels

# %%
# Fit a basic classification tree to the denver data with HF3 as labels

features = denver[[
    "asst_idx_z", "lvstk_idx_z", "prod_idx_z", "hrv_value_z",
    "LGhrv_value_z", "exp_total_ap_z", "LGnfe_rev_z",
    "nfe_z", "inc_rev_idxSD_z", "fin_debt_idxSD_z"]]

labels = denver["HF3"]

train_test_eval(features, labels, "denver_hf3")
# Out:
# Trial #1:
# Misclassified 112 of 304 points | MCR = 0.3684210526315789
# Five most useful features:
#       feature_name  importance
# 2       prod_idx_z    0.257060
# 8  inc_rev_idxSD_z    0.183441
# 0       asst_idx_z    0.141644
# 3      hrv_value_z    0.114586
# 4    LGhrv_value_z    0.087649
#
# Trial #2:
# Misclassified 104 of 304 points | MCR = 0.34210526315789475
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.297358
# 8   inc_rev_idxSD_z    0.133525
# 9  fin_debt_idxSD_z    0.118734
# 3       hrv_value_z    0.108542
# 0        asst_idx_z    0.106774
#
# Trial #3:
# Misclassified 107 of 304 points | MCR = 0.3519736842105263
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.177489
# 0        asst_idx_z    0.176811
# 3       hrv_value_z    0.137124
# 9  fin_debt_idxSD_z    0.123764
# 8   inc_rev_idxSD_z    0.115436
#
# Trial #4:
# Misclassified 109 of 304 points | MCR = 0.35855263157894735
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.196507
# 0        asst_idx_z    0.174322
# 3       hrv_value_z    0.161960
# 9  fin_debt_idxSD_z    0.102526
# 8   inc_rev_idxSD_z    0.102019
#
# Trial #5:
# Misclassified 110 of 304 points | MCR = 0.3618421052631579
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.188685
# 8   inc_rev_idxSD_z    0.160352
# 0        asst_idx_z    0.148621
# 3       hrv_value_z    0.118592
# 9  fin_debt_idxSD_z    0.117997
#
# Trial #6:
# Misclassified 109 of 304 points | MCR = 0.35855263157894735
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.259216
# 0        asst_idx_z    0.140055
# 8   inc_rev_idxSD_z    0.139204
# 9  fin_debt_idxSD_z    0.115611
# 1       lvstk_idx_z    0.113626
#
# Trial #7:
# Misclassified 96 of 304 points | MCR = 0.3157894736842105
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.165047
# 0        asst_idx_z    0.156299
# 2        prod_idx_z    0.142343
# 5    exp_total_ap_z    0.111427
# 1       lvstk_idx_z    0.105595
#
# Trial #8:
# Misclassified 110 of 304 points | MCR = 0.3618421052631579
# Five most useful features:
#        feature_name  importance
# 4     LGhrv_value_z    0.189115
# 0        asst_idx_z    0.172350
# 2        prod_idx_z    0.161278
# 8   inc_rev_idxSD_z    0.139919
# 9  fin_debt_idxSD_z    0.108486
#
# Trial #9:
# Misclassified 111 of 304 points | MCR = 0.3651315789473684
# Five most useful features:
#       feature_name  importance
# 2       prod_idx_z    0.270455
# 0       asst_idx_z    0.150799
# 8  inc_rev_idxSD_z    0.138471
# 1      lvstk_idx_z    0.123029
# 5   exp_total_ap_z    0.112593
#
# Trial #10:
# Misclassified 116 of 304 points | MCR = 0.3815789473684211
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.192382
# 9  fin_debt_idxSD_z    0.189259
# 8   inc_rev_idxSD_z    0.181939
# 3       hrv_value_z    0.131969
# 0        asst_idx_z    0.126041
#
# Trial #11:
# Misclassified 113 of 304 points | MCR = 0.3717105263157895
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.165593
# 0        asst_idx_z    0.161162
# 1       lvstk_idx_z    0.160384
# 9  fin_debt_idxSD_z    0.118532
# 3       hrv_value_z    0.106374
#
# Trial #12:
# Misclassified 115 of 304 points | MCR = 0.3782894736842105
# Five most useful features:
#       feature_name  importance
# 2       prod_idx_z    0.222753
# 0       asst_idx_z    0.209865
# 4    LGhrv_value_z    0.127386
# 8  inc_rev_idxSD_z    0.112902
# 1      lvstk_idx_z    0.109008
#
# Trial #13:
# Misclassified 114 of 304 points | MCR = 0.375
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.208156
# 8   inc_rev_idxSD_z    0.174164
# 2        prod_idx_z    0.158215
# 9  fin_debt_idxSD_z    0.116179
# 1       lvstk_idx_z    0.105114
#
# Trial #14:
# Misclassified 110 of 304 points | MCR = 0.3618421052631579
# Five most useful features:
#     feature_name  importance
# 2     prod_idx_z    0.202111
# 3    hrv_value_z    0.146413
# 0     asst_idx_z    0.133513
# 1    lvstk_idx_z    0.120153
# 4  LGhrv_value_z    0.103311
#
# Trial #15:
# Misclassified 102 of 304 points | MCR = 0.3355263157894737
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.201771
# 2        prod_idx_z    0.169690
# 8   inc_rev_idxSD_z    0.161013
# 1       lvstk_idx_z    0.105024
# 9  fin_debt_idxSD_z    0.099965
#
# Trial #16:
# Misclassified 107 of 304 points | MCR = 0.3519736842105263
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.268148
# 8   inc_rev_idxSD_z    0.174857
# 0        asst_idx_z    0.147497
# 9  fin_debt_idxSD_z    0.146555
# 4     LGhrv_value_z    0.101759
#
# Trial #17:
# Misclassified 108 of 304 points | MCR = 0.35526315789473684
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.209922
# 8   inc_rev_idxSD_z    0.154721
# 0        asst_idx_z    0.126983
# 9  fin_debt_idxSD_z    0.121095
# 4     LGhrv_value_z    0.116537
#
# Trial #18:
# Misclassified 102 of 304 points | MCR = 0.3355263157894737
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.206458
# 2        prod_idx_z    0.205405
# 9  fin_debt_idxSD_z    0.144556
# 3       hrv_value_z    0.106073
# 4     LGhrv_value_z    0.098037
#
# Trial #19:
# Misclassified 99 of 304 points | MCR = 0.3256578947368421
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.195332
# 8   inc_rev_idxSD_z    0.149137
# 0        asst_idx_z    0.148444
# 9  fin_debt_idxSD_z    0.126150
# 4     LGhrv_value_z    0.104299
#
# Trial #20:
# Misclassified 116 of 304 points | MCR = 0.3815789473684211
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.169988
# 4     LGhrv_value_z    0.153867
# 8   inc_rev_idxSD_z    0.146652
# 9  fin_debt_idxSD_z    0.137908
# 0        asst_idx_z    0.137116
#
# Trial #21:
# Misclassified 98 of 304 points | MCR = 0.3223684210526316
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.226689
# 0        asst_idx_z    0.158042
# 8   inc_rev_idxSD_z    0.136373
# 4     LGhrv_value_z    0.121636
# 9  fin_debt_idxSD_z    0.103688
#
# Trial #22:
# Misclassified 104 of 304 points | MCR = 0.34210526315789475
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.210943
# 2        prod_idx_z    0.195140
# 8   inc_rev_idxSD_z    0.187764
# 4     LGhrv_value_z    0.124767
# 9  fin_debt_idxSD_z    0.084913
#
# Trial #23:
# Misclassified 108 of 304 points | MCR = 0.35526315789473684
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.264268
# 3       hrv_value_z    0.162671
# 8   inc_rev_idxSD_z    0.146798
# 0        asst_idx_z    0.109201
# 9  fin_debt_idxSD_z    0.103783
#
# Trial #24:
# Misclassified 111 of 304 points | MCR = 0.3651315789473684
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.173779
# 8   inc_rev_idxSD_z    0.168222
# 2        prod_idx_z    0.134585
# 9  fin_debt_idxSD_z    0.132760
# 1       lvstk_idx_z    0.112329
#
# Trial #25:
# Misclassified 112 of 304 points | MCR = 0.3684210526315789
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.236620
# 8   inc_rev_idxSD_z    0.161910
# 2        prod_idx_z    0.158597
# 9  fin_debt_idxSD_z    0.113931
# 3       hrv_value_z    0.109516
#
# Trial #26:
# Misclassified 106 of 304 points | MCR = 0.34868421052631576
# Five most useful features:
#        feature_name  importance
# 3       hrv_value_z    0.182833
# 2        prod_idx_z    0.180552
# 8   inc_rev_idxSD_z    0.179142
# 9  fin_debt_idxSD_z    0.141542
# 0        asst_idx_z    0.107637
#
# Trial #27:
# Misclassified 101 of 304 points | MCR = 0.33223684210526316
# Five most useful features:
#        feature_name  importance
# 8   inc_rev_idxSD_z    0.188588
# 0        asst_idx_z    0.167296
# 2        prod_idx_z    0.160946
# 9  fin_debt_idxSD_z    0.124187
# 3       hrv_value_z    0.121283
#
# Trial #28:
# Misclassified 96 of 304 points | MCR = 0.3157894736842105
# Five most useful features:
#        feature_name  importance
# 8   inc_rev_idxSD_z    0.211863
# 0        asst_idx_z    0.154757
# 2        prod_idx_z    0.144722
# 9  fin_debt_idxSD_z    0.134376
# 3       hrv_value_z    0.099804
#
# Trial #29:
# Misclassified 103 of 304 points | MCR = 0.33881578947368424
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.196394
# 8   inc_rev_idxSD_z    0.175242
# 0        asst_idx_z    0.144793
# 9  fin_debt_idxSD_z    0.130091
# 1       lvstk_idx_z    0.112475
#
# Trial #30:
# Misclassified 104 of 304 points | MCR = 0.34210526315789475
# Five most useful features:
#       feature_name  importance
# 2       prod_idx_z    0.183466
# 0       asst_idx_z    0.163439
# 8  inc_rev_idxSD_z    0.137164
# 1      lvstk_idx_z    0.119369
# 4    LGhrv_value_z    0.104561
#
# Trial #31:
# Misclassified 100 of 304 points | MCR = 0.32894736842105265
# Five most useful features:
#        feature_name  importance
# 8   inc_rev_idxSD_z    0.217309
# 0        asst_idx_z    0.170083
# 2        prod_idx_z    0.153912
# 4     LGhrv_value_z    0.146599
# 9  fin_debt_idxSD_z    0.117402
#
# Trial #32:
# Misclassified 112 of 304 points | MCR = 0.3684210526315789
# Five most useful features:
#       feature_name  importance
# 8  inc_rev_idxSD_z    0.184319
# 2       prod_idx_z    0.163201
# 0       asst_idx_z    0.148374
# 4    LGhrv_value_z    0.117425
# 3      hrv_value_z    0.116335
#
# Trial #33:
# Misclassified 104 of 304 points | MCR = 0.34210526315789475
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.243545
# 0        asst_idx_z    0.155266
# 9  fin_debt_idxSD_z    0.148850
# 8   inc_rev_idxSD_z    0.117615
# 1       lvstk_idx_z    0.100961
#
# Trial #34:
# Misclassified 103 of 304 points | MCR = 0.33881578947368424
# Five most useful features:
#       feature_name  importance
# 8  inc_rev_idxSD_z    0.169885
# 2       prod_idx_z    0.169435
# 0       asst_idx_z    0.167455
# 3      hrv_value_z    0.143485
# 1      lvstk_idx_z    0.106139
#
# Trial #35:
# Misclassified 112 of 304 points | MCR = 0.3684210526315789
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.278281
# 8   inc_rev_idxSD_z    0.216435
# 0        asst_idx_z    0.122308
# 9  fin_debt_idxSD_z    0.107254
# 5    exp_total_ap_z    0.071918
#
# Trial #36:
# Misclassified 114 of 304 points | MCR = 0.375
# Five most useful features:
#        feature_name  importance
# 0        asst_idx_z    0.212324
# 2        prod_idx_z    0.193769
# 4     LGhrv_value_z    0.136626
# 9  fin_debt_idxSD_z    0.115479
# 8   inc_rev_idxSD_z    0.083863
#
# Trial #37:
# Misclassified 114 of 304 points | MCR = 0.375
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.182159
# 2        prod_idx_z    0.167066
# 1       lvstk_idx_z    0.142981
# 8   inc_rev_idxSD_z    0.133923
# 0        asst_idx_z    0.129976
#
# Trial #38:
# Misclassified 90 of 304 points | MCR = 0.29605263157894735
# Five most useful features:
#       feature_name  importance
# 8  inc_rev_idxSD_z    0.211790
# 0       asst_idx_z    0.165171
# 2       prod_idx_z    0.159928
# 3      hrv_value_z    0.127175
# 1      lvstk_idx_z    0.097728
#
# Trial #39:
# Misclassified 113 of 304 points | MCR = 0.3717105263157895
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.215539
# 0        asst_idx_z    0.155558
# 4     LGhrv_value_z    0.119773
# 9  fin_debt_idxSD_z    0.107830
# 8   inc_rev_idxSD_z    0.102027
#
# Trial #40:
# Misclassified 99 of 304 points | MCR = 0.3256578947368421
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.196623
# 8   inc_rev_idxSD_z    0.161229
# 0        asst_idx_z    0.142446
# 9  fin_debt_idxSD_z    0.111881
# 3       hrv_value_z    0.102031
#
# Trial #41:
# Misclassified 104 of 304 points | MCR = 0.34210526315789475
# Five most useful features:
#        feature_name  importance
# 8   inc_rev_idxSD_z    0.202246
# 0        asst_idx_z    0.173719
# 9  fin_debt_idxSD_z    0.132431
# 2        prod_idx_z    0.118275
# 4     LGhrv_value_z    0.116237
#
# Trial #42:
# Misclassified 106 of 304 points | MCR = 0.34868421052631576
# Five most useful features:
#       feature_name  importance
# 2       prod_idx_z    0.207329
# 8  inc_rev_idxSD_z    0.147456
# 3      hrv_value_z    0.122459
# 0       asst_idx_z    0.122417
# 4    LGhrv_value_z    0.096764
#
# Trial #43:
# Misclassified 125 of 304 points | MCR = 0.41118421052631576
# Five most useful features:
#        feature_name  importance
# 8   inc_rev_idxSD_z    0.182943
# 0        asst_idx_z    0.164199
# 3       hrv_value_z    0.152131
# 9  fin_debt_idxSD_z    0.151658
# 2        prod_idx_z    0.147899
# Trial #44:
# Misclassified 116 of 304 points | MCR = 0.3815789473684211
# Five most useful features:
#       feature_name  importance
# 8  inc_rev_idxSD_z    0.195173
# 0       asst_idx_z    0.172494
# 2       prod_idx_z    0.131354
# 1      lvstk_idx_z    0.120053
# 4    LGhrv_value_z    0.106409
#
# Trial #45:
# Misclassified 107 of 304 points | MCR = 0.3519736842105263
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.209511
# 0        asst_idx_z    0.147358
# 4     LGhrv_value_z    0.134963
# 8   inc_rev_idxSD_z    0.126900
# 9  fin_debt_idxSD_z    0.119606
#
# Trial #46:
# Misclassified 98 of 304 points | MCR = 0.3223684210526316
# Five most useful features:
#       feature_name  importance
# 0       asst_idx_z    0.245130
# 2       prod_idx_z    0.172847
# 5   exp_total_ap_z    0.108658
# 8  inc_rev_idxSD_z    0.103445
# 4    LGhrv_value_z    0.083660
#
# Trial #47:
# Misclassified 94 of 304 points | MCR = 0.3092105263157895
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.191696
# 4     LGhrv_value_z    0.184662
# 9  fin_debt_idxSD_z    0.143410
# 8   inc_rev_idxSD_z    0.108840
# 3       hrv_value_z    0.103411
#
# Trial #48:
# Misclassified 109 of 304 points | MCR = 0.35855263157894735
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.221450
# 0        asst_idx_z    0.179340
# 9  fin_debt_idxSD_z    0.127730
# 8   inc_rev_idxSD_z    0.121483
# 1       lvstk_idx_z    0.113530
#
# Trial #49:
# Misclassified 102 of 304 points | MCR = 0.3355263157894737
# Five most useful features:
#        feature_name  importance
# 2        prod_idx_z    0.171071
# 9  fin_debt_idxSD_z    0.164858
# 0        asst_idx_z    0.159884
# 4     LGhrv_value_z    0.104886
# 8   inc_rev_idxSD_z    0.099196
#
# Trial #50:
# Misclassified 109 of 304 points | MCR = 0.35855263157894735
# Five most useful features:
#        feature_name  importance
# 9  fin_debt_idxSD_z    0.180013
# 0        asst_idx_z    0.162038
# 3       hrv_value_z    0.157346
# 2        prod_idx_z    0.129422
# 1       lvstk_idx_z    0.103136
